# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_context("talk")

# %%
full_df = pd.read_csv('full_df.csv')
full_df
# Out:
#        Unnamed: 0  level_0  index    IMAGE_SERIES       Label  TRACK_ID  \
# 0               0        0  21728  Huh7_B4_Pickup     Track_0         0
# 1               1        1  21729  Huh7_B4_Pickup     Track_1         1
# 2               2        2  21730  Huh7_B4_Pickup     Track_2         2
# 3               3        3  21731  Huh7_B4_Pickup     Track_3         3
# 4               4        4  21732  Huh7_B4_Pickup     Track_4         4
# ...           ...      ...    ...             ...         ...       ...
# 19636       19636     7326   7326         PRF5_D3  Track_1777      1777
# 19637       19637     7327   7327         PRF5_D3  Track_1778      1778
# 19638       19638     7328   7328         PRF5_D3  Track_1779      1779
# 19639       19639     7329   7329         PRF5_D3  Track_1780      1780
# 19640       19640     7330   7330         PRF5_D3  Track_1781      1781
#
#        NUMBER_SPOTS  NUMBER_GAPS  LONGEST_GAP  NUMBER_SPLITS  ...  \
# 0                16            0            0              0  ...
# 1               145            0            0              0  ...
# 2                 9            0            0              0  ...
# 3                38            1            1              0  ...
# 4                 2            0            0              0  ...
# ...             ...          ...          ...            ...  ...
# 19636             2            0            0              0  ...
# 19637             2            0            0              0  ...
# 19638             2            0            0              0  ...
# 19639             2            0            0              0  ...
# 19640             2            0            0              0  ...
#
#        TRACK_MAX_SPEED  TRACK_MIN_SPEED  TRACK_MEDIAN_SPEED  TRACK_STD_SPEED  \
# 0               17.739            0.954               5.290            5.195
# 1               17.000            0.000               0.000            1.500
# 2               24.749            1.784               8.037            9.406
# 3               20.797            0.643               6.405            4.887
# 4               15.579           15.579              15.579              NaN
# ...                ...              ...                 ...              ...
# 19636            5.000            5.000               5.000              NaN
# 19637            7.176            7.176               7.176              NaN
# 19638           10.938           10.938              10.938              NaN
# 19639            7.217            7.217               7.217              NaN
# 19640            7.341            7.341               7.341              NaN
#
#        TRACK_MEAN_QUALITY  TRACK_MAX_QUALITY  TRACK_MIN_QUALITY  \
# 0                   0.083              0.100              0.045
# 1                   0.084              0.126              0.044
# 2                   0.082              0.094              0.071
# 3                   0.087              0.111              0.046
# 4                   0.050              0.054              0.047
# ...                   ...                ...                ...
# 19636               0.051              0.060              0.041
# 19637               0.080              0.104              0.056
# 19638               0.048              0.049              0.048
# 19639               0.052              0.054              0.050
# 19640               0.041              0.042              0.040
#
#        TRACK_MEDIAN_QUALITY  TRACK_STD_QUALITY  cell_line
# 0                     0.088           0.015000       Huh7
# 1                     0.093           0.020000       Huh7
# 2                     0.082           0.008000       Huh7
# 3                     0.090           0.018000       Huh7
# 4                     0.054           0.003000       Huh7
# ...                     ...                ...        ...
# 19636                 0.060           0.010000       PRF5
# 19637                 0.104           0.024000       PRF5
# 19638                 0.049           0.000168       PRF5
# 19639                 0.054           0.002000       PRF5
# 19640                 0.042           0.000816       PRF5
#
# [19641 rows x 31 columns]

# %%
cell_lines = ['PRF5_B3_pickup', 'PRF5_A3', 'PRF5_C3', 'PRF5_D3', 'JHH4_B2',
       'JHH4_A2', 'JHH6_A1', 'JHH6_B1', 'JHH6_D1', 'JHH6_C1_pickup',
       'JHH7_C5', 'JHH7_D5', 'JHH7_A5', 'JHH7_B5_pickup', 'JHH7_2.5uM_n2',
       'JHH7_2.5uM_n3', 'JHH7_2.5uM_n4', 'JHH7_2.5uM_n1', 'JHH6_2.5uM_n2',
       'JHH6_2.5uM_n3', 'JHH6_2.5uM_n4', 'JHH6_2.5uM_n1', 'JHH7_0uM_n1',
       'JHH7_0uM_n4', 'JHH7_0uM_n3', 'JHH7_0uM_n2', 'JHH6_0uM_n2',
       'JHH6_0uM_n3', 'JHH6_0uM_n4', 'JHH6_0uM_n1', 'JHH7_1uM_n1',
       'JHH7_1uM_n2', 'JHH7_1uM_n3', 'JHH7_1uM_n4', 'JHH6_1uM_n4',
       'JHH6_1uM_n3', 'JHH6_1uM_n2', 'JHH6_1uM_n1', 'Huh7_B4_Pickup',
       'Huh7_A4', 'Huh7_C4', 'Huh7_D4', 'Kami41_A6', 'Kami41_C6',
       'Kami41_D6', 'Kami41_B6_pickup']

# %%
full_TRACK_MEAN_SPEED_df = full_df[['TRACK_MEAN_SPEED', 'cell_line']]

# %%
sns.displot(full_TRACK_MEAN_SPEED_df, x='TRACK_MEAN_SPEED', hue='cell_line', 
            kind="kde", bw_adjust=.3, height=5, aspect=15/8).set(title='Figure A. Track mean speed by cell line, no treatment')

# %%
sns.boxplot(data=full_TRACK_MEAN_SPEED_df, x='cell_line', y='TRACK_MEAN_SPEED').set(title='Figure B. Track mean speed by cell line, no treatment')
sns.set(rc={'figure.figsize':(10,8)})
sns.set(font_scale = 1)

# %%
sns.displot(data=full_TRACK_MEAN_SPEED_df, y='TRACK_MEAN_SPEED', x='cell_line', 
            height=5, aspect=15/8).set(title='Track mean speed by cell line, no treatment')
